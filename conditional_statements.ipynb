# %% [markdown]
# # conditional statementes in python
# 1. python have 4 types of conditional statementes
# 2. `if` statement
# 3. `else` statement
# 4. `else` statement
# 5. `nested` statements
#
#   ```python
#   if(condition);
#   statements
#   statements..
#
#   ```pthon if
#   if(condition):
#       statements
#     statements..
#  else
#       statements
#       statements..
# ```
#
# ```python if ,elif,else
# if(condition);
#    statement
#    elif(condition);
#    statements
#    else;
#         statement..
#    ```

# %%
#write a program to find the given number is even number 
num=int(input("please enter number here:"))
if(num%2 ==0):
    print(num,"is even number")
# Out:
# please enter number here: 123

# %%
10%2
# Out:
# 0

# %%
# write a program to find the given number  is even number  or odd number 
number = int(input("please enter number here:"))
if (number%2 == 0):
    print(number, "is odd number")
else:
    print(number,"is odd number")
# Out:
# please enter number her: 964062
# 964062 is odd number

# %%
# write a program to find a number is positive , negative or zero
number=int(input("please enter anumber here:"))
if (number>0):
    print(number,"is a positive number ")
elif(number<0):
    print(number,"is a negative number")
else:
    print(number,"is zero")
# Out:
# please enter anumber here: 0
# 0 is zero

# %%
# write a program to find a number is positive , negative or zero
number=int(input("please enter anumber here:"))
if (number>0):
    print(number,"is a positive number ")
elif(number<0):
    print(number,"is a negative number")
else:
    print(number,"is zero")
# Out:
# please enter anumber here: 9
# 9 is a positive number

# %%
# write a program to find a number is positive , negative or zero
number=int(input("please enter anumber here:"))
if (number>0):
    print(number,"is a positive number ")
elif(number<0):
    print(number,"is a negative number")
else:
    print(number,"is zero")
# Out:
# please enter anumber here: -5
# -5 is a negative number

# %%
"""
write a program to find the student grades on marks
1.if student marks  in betwen 100 to 80 then grade is A
2.if student marks  in betwen 79 to 60 then grade is B
3.if student marks  in betwen 59 to 40 then grade is C
4.if student marks  in betwen 39 to 25 then grade is D
5.if student marks  in betwen 24 to 0 then grade is fail
6.if other than above  marks expected output should be pease enter correct marks
"""

m=int(input("enter your marks"))
if(m>=80 and m<=100):
    print("your grade is A")
elif(m>=60 and m<=79):
    printe ("your grade is B")
elif(m>=40 and m<=59):
    print ("your grade is C")
elif(m>=25 and m<=39):
    print ("your grade is D")
elif(m>=0 and m<=24):
    print("you failed")
else:
      print("please enter correct marks!")
# Out:
# enter your marks 100
# your grade is A

# %%
#write a program to find to find the largest number among three numbers
a=int(input("Enter first number: ")) 
b=int(input("Enter second number: ")) 
c=int(input("Enter third number: ")) 
if a >= b and a >= c:
    print("first number is the largest number.") 
elif b >= a and b >= c:
    print("second number: is the largest number.")
else: 
    print("third number is the largest number.")
# Out:
# Enter first number:  0
# Enter second number:  8
# Enter third number:  9
# third number is the largest number.

# %%
#write a program to  validate  loin credentials using conditional statements 
username=str(input("please enter username here:))
   if(username=="vathyavathsharathnaayak@gmail.com" and password ==  sharath@77
      print("login successful!")
else:
     print("invalid credentials.")
# Out:
#   Cell In[6], line 2
#     username=str(input("please enter username here:))
#                        ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
''' write a program to find then even number wuth number of digits
#1. if number in between 1 to 9 then output is one digit even number
#2. if number in between 10 to 99 then output is two digit even number 
#3. if number in between 100 to 999 then output is three digit even number
#4. if number in between 1000 to 9999 then output is four digit even number 
#5. if number is other than above then output is weired even number 
'''
num=int(input("Enter a number: ")) 
if 1 <= num <= 9 and num % 2 == 0:
    print("One digit even number")
elif 10 <= num <= 99 and num % 2 == 0:
    print("Two digit even number")
elif 100 <= num <= 999 and num % 2 == 0:
    print("Three digit even number")
elif 1000 <= num <= 9999 and num % 2 == 0:
    print("Four digit even number") 
else: print("Weired even number")
# Out:
# Enter a number:  2177
# Weired even number

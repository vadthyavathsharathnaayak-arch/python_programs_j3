# %%
#operators in python 
## 6 types of operators in python 
1.arithematic opertors 
2. assigment opertors
3.comarical opertors 
4.logical opertors
5.membership opertors 
6. identity opertors

# %%
# arithenatic opertors -+,-,*,/,//,%
a=10
b=20
c=20
d=30
print(a+b)
print(b-c)
print(b*d)
print(d/a)
print(b//a)
print(d%a)
# Out:
# 30
# 0
# 600
# 3.0
# 2
# 0

# %%
#assigent opertors-+=,*=/=,//=,%=
a=100
a+=50
print(a)
# Out:
# 150

# %%
b=200
b-=400
print(b)
# Out:
# -200

# %%
c=50
c*=100 
print(c)
# Out:
# 5000

# %%
# comparision operaton ->,<,>=,<=,==,!=
a=10
b=20
d=30
print(a>b)
print(b==c)
print(b<c)
print(b!=c)
print(b>=a)
print(b<=a)
# Out:
# False
# False
# True
# True
# True
# False

# %%
#logical operators -and, or, not
"""
and-both condition are true then results is true , rest it false
or -either one condition is true the result is true, rest case result is false
and true table 
TT=T
TF=F
FT=F
FF=F
OR TRUE TABLE
TT=T
TF=T
FT=T
FF=F
"""

A=10
B=20
D=30
print(a>b and b==c)
print(a<b and c==b)
print(a>b and b==c)
print(a>b and b==c)
# Out:
# False
# False
# False
# False

# %%
# membership opertors - in,not in
# volidating member are present in the squence or group
names=["vikas","shivaji","sidh","chndra"]
print("vikas" in names)
print("shivaji" in names)
print("vikas" in names)
print("vikram" in names)
# Out:
# True
# True
# True
# False

# %%
#identity operars -is,is,not
a=10000
b=10000
print(a is b)
print(id(a))
print(id(b))
# Out:
# False
# 1971214335088
# 1971214334960

# %%
a=10
b=10
print(a is b)
print
